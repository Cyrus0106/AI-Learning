# %% [markdown]
# # Deep Q-Networks (DQN) Implementation in Python

# %% [markdown]
# #### Deep Q-Networks (DQN)
# Deep Q-Networks (DQN) is a reinforcement learning algorithm that combines Q-learning with deep neural networks. It uses a neural network to approximate the Q-values for each action in a given state, allowing it to handle environmnets with high-dimensional and continuous state spaces. DQN uses experience replay (storing past experiences and training on random batches) and a target networks to stabilise training

# %%
import gymnasium as gym 
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import random
from collections import deque

# Define the DQN model
class DQN(nn.Module):
    def __init__(self, input_size, output_size):
        super(DQN, self).__init__()
        self.linear1 = nn.Linear(input_size, 64)
        self.linear2 = nn.Linear(64, 32) 
        self.linear3 = nn.Linear(32, output_size)

    def forward(self, x):
        x = torch.relu(self.linear1(x))
        x = torch.relu(self.linear2(x))
        return self.linear3(x)
    
# Hyperparameters
env_name = 'CartPole-v1'
learning_rate = 0.001
batch_size = 32  # Fixed: removed duplicate definition
gamma = 0.99
buffer_size = 10000
epsilon = 0.1
target_update_freq = 100

# Initialize environment and DQN
env = gym.make(env_name)
input_size = env.observation_space.shape[0]
output_size = env.action_space.n    

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
policy_net = DQN(input_size, output_size).to(device)
target_net = DQN(input_size, output_size).to(device)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()
optimizer = optim.Adam(policy_net.parameters(), lr=learning_rate)
criterion = nn.MSELoss()

# Experience replay buffer - using deque for better performance
replay_buffer = deque(maxlen=buffer_size)
 
def train(num_episodes):
    step_count = 0  # Initialize step count

    for episode in range(num_episodes):
        # Handle both old and new gym API
        reset_result = env.reset()
        if isinstance(reset_result, tuple):
            state, _ = reset_result
        else:
            state = reset_result
        
        state = np.array(state)
        total_reward = 0  # Fixed: initialize total_reward for each episode
        done = False
        
        while not done:
            # Epsilon-greedy action selection
            if random.random() < epsilon:
                action = env.action_space.sample()
            else:
                with torch.no_grad():
                    action = policy_net(torch.tensor(state, dtype=torch.float32, device=device)).argmax().item()

            # Take action and observe reward and next state
            step_result = env.step(action)
            
            # Handle different gym API versions
            if len(step_result) == 5:
                next_state, reward, done, truncated, _ = step_result
                done = done or truncated
            else:
                next_state, reward, done, _ = step_result
                
            next_state = np.array(next_state)
            total_reward += reward

            # Store experience in replay buffer 
            replay_buffer.append((state, action, reward, next_state, done))

            # Update current state
            state = next_state

            # Sample batch from replay buffer and train
            if len(replay_buffer) >= batch_size:
                batch = random.sample(replay_buffer, batch_size)
                states, actions, rewards, next_states, dones = zip(*batch)

                # Convert to tensors and move to device
                states = torch.tensor(np.array(states), dtype=torch.float32, device=device)
                actions = torch.tensor(actions, dtype=torch.long, device=device)
                rewards = torch.tensor(rewards, dtype=torch.float32, device=device)
                next_states = torch.tensor(np.array(next_states), dtype=torch.float32, device=device)
                dones = torch.tensor(dones, dtype=torch.float32, device=device)

                # Compute Q-values and target Q-values
                current_q_values = policy_net(states).gather(1, actions.unsqueeze(1))
                next_q_values = target_net(next_states).max(1)[0].detach()
                target_q_values = rewards + gamma * next_q_values * (1 - dones)

                # Compute loss and update policy network
                loss = criterion(current_q_values, target_q_values.unsqueeze(1))
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

                # Update target network periodically
                step_count += 1
                if step_count % target_update_freq == 0:
                    target_net.load_state_dict(policy_net.state_dict())

        print(f"Episode {episode+1}: Total reward = {total_reward}")

# Train the agent
train(num_episodes=1000)
# Out:
# Episode 1: Total reward = 10.0
# Episode 2: Total reward = 10.0
# Episode 3: Total reward = 12.0
# Episode 4: Total reward = 9.0
# Episode 5: Total reward = 11.0
# Episode 6: Total reward = 8.0
# Episode 7: Total reward = 10.0
# Episode 8: Total reward = 10.0
# Episode 9: Total reward = 9.0
# Episode 10: Total reward = 10.0
# Episode 11: Total reward = 10.0
# Episode 12: Total reward = 11.0
# Episode 13: Total reward = 10.0
# Episode 14: Total reward = 11.0
# Episode 15: Total reward = 10.0
# Episode 16: Total reward = 11.0
# Episode 17: Total reward = 10.0
# Episode 18: Total reward = 9.0
# Episode 19: Total reward = 12.0
# Episode 20: Total reward = 10.0
# Episode 21: Total reward = 11.0
# Episode 22: Total reward = 10.0
# Episode 23: Total reward = 9.0
# Episode 24: Total reward = 10.0
# Episode 25: Total reward = 9.0
# Episode 26: Total reward = 9.0
# Episode 27: Total reward = 10.0
# Episode 28: Total reward = 10.0
# Episode 29: Total reward = 10.0
# Episode 30: Total reward = 9.0
# Episode 31: Total reward = 10.0
# Episode 32: Total reward = 11.0
# Episode 33: Total reward = 10.0
# Episode 34: Total reward = 9.0
# Episode 35: Total reward = 10.0
# Episode 36: Total reward = 9.0
# Episode 37: Total reward = 9.0
# Episode 38: Total reward = 9.0
# Episode 39: Total reward = 10.0
# Episode 40: Total reward = 9.0
# Episode 41: Total reward = 10.0
# Episode 42: Total reward = 10.0
# Episode 43: Total reward = 9.0
# Episode 44: Total reward = 10.0
# Episode 45: Total reward = 14.0
# Episode 46: Total reward = 9.0
# Episode 47: Total reward = 10.0
# Episode 48: Total reward = 9.0
# Episode 49: Total reward = 9.0
# Episode 50: Total reward = 9.0
# Episode 51: Total reward = 10.0
# Episode 52: Total reward = 9.0
# Episode 53: Total reward = 9.0
# Episode 54: Total reward = 10.0
# Episode 55: Total reward = 11.0
# Episode 56: Total reward = 11.0
# Episode 57: Total reward = 11.0
# Episode 58: Total reward = 9.0
# Episode 59: Total reward = 10.0
# Episode 60: Total reward = 12.0
# Episode 61: Total reward = 8.0
# Episode 62: Total reward = 12.0
# Episode 63: Total reward = 10.0
# Episode 64: Total reward = 11.0
# Episode 65: Total reward = 10.0
# Episode 66: Total reward = 12.0
# Episode 67: Total reward = 9.0
# Episode 68: Total reward = 10.0
# Episode 69: Total reward = 10.0
# Episode 70: Total reward = 12.0
# Episode 71: Total reward = 12.0
# Episode 72: Total reward = 10.0
# Episode 73: Total reward = 8.0
# Episode 74: Total reward = 8.0
# Episode 75: Total reward = 9.0
# Episode 76: Total reward = 10.0
# Episode 77: Total reward = 11.0
# Episode 78: Total reward = 11.0
# Episode 79: Total reward = 10.0
# Episode 80: Total reward = 9.0
# Episode 81: Total reward = 14.0
# Episode 82: Total reward = 9.0
# Episode 83: Total reward = 10.0
# Episode 84: Total reward = 9.0
# Episode 85: Total reward = 10.0
# Episode 86: Total reward = 12.0
# Episode 87: Total reward = 11.0
# Episode 88: Total reward = 30.0
# Episode 89: Total reward = 13.0
# Episode 90: Total reward = 18.0
# Episode 91: Total reward = 38.0
# Episode 92: Total reward = 43.0
# Episode 93: Total reward = 26.0
# Episode 94: Total reward = 23.0
# Episode 95: Total reward = 18.0
# Episode 96: Total reward = 16.0
# Episode 97: Total reward = 65.0
# Episode 98: Total reward = 46.0
# Episode 99: Total reward = 63.0
# Episode 100: Total reward = 42.0
# Episode 101: Total reward = 91.0
# Episode 102: Total reward = 68.0
# Episode 103: Total reward = 50.0
# Episode 104: Total reward = 48.0
# Episode 105: Total reward = 89.0
# Episode 106: Total reward = 65.0
# Episode 107: Total reward = 64.0
# Episode 108: Total reward = 82.0
# Episode 109: Total reward = 69.0
# Episode 110: Total reward = 69.0
# Episode 111: Total reward = 72.0
# Episode 112: Total reward = 130.0
# Episode 113: Total reward = 291.0
# Episode 114: Total reward = 95.0
# Episode 115: Total reward = 129.0
# Episode 116: Total reward = 275.0
# Episode 117: Total reward = 214.0
# Episode 118: Total reward = 166.0
# Episode 119: Total reward = 186.0
# Episode 120: Total reward = 197.0
# Episode 121: Total reward = 195.0
# Episode 122: Total reward = 168.0
# Episode 123: Total reward = 295.0
# Episode 124: Total reward = 311.0
# Episode 125: Total reward = 462.0
# Episode 126: Total reward = 259.0
# Episode 127: Total reward = 327.0
# Episode 128: Total reward = 257.0
# Episode 129: Total reward = 354.0
# Episode 130: Total reward = 386.0
# Episode 131: Total reward = 320.0
# Episode 132: Total reward = 179.0
# Episode 133: Total reward = 243.0
# Episode 134: Total reward = 185.0
# Episode 135: Total reward = 311.0
# Episode 136: Total reward = 267.0
# Episode 137: Total reward = 186.0
# Episode 138: Total reward = 242.0
# Episode 139: Total reward = 200.0
# Episode 140: Total reward = 177.0
# Episode 141: Total reward = 284.0
# Episode 142: Total reward = 247.0
# Episode 143: Total reward = 165.0
# Episode 144: Total reward = 191.0
# Episode 145: Total reward = 197.0
# Episode 146: Total reward = 200.0
# Episode 147: Total reward = 215.0
# Episode 148: Total reward = 191.0
# Episode 149: Total reward = 187.0
# Episode 150: Total reward = 191.0
# Episode 151: Total reward = 243.0
# Episode 152: Total reward = 162.0
# Episode 153: Total reward = 320.0
# Episode 154: Total reward = 213.0
# Episode 155: Total reward = 177.0
# Episode 156: Total reward = 201.0
# Episode 157: Total reward = 204.0
# Episode 158: Total reward = 207.0
# Episode 159: Total reward = 218.0
# Episode 160: Total reward = 225.0
# Episode 161: Total reward = 229.0
# Episode 162: Total reward = 294.0
# Episode 163: Total reward = 369.0
# Episode 164: Total reward = 183.0
# Episode 165: Total reward = 199.0
# Episode 166: Total reward = 245.0
# Episode 167: Total reward = 198.0
# Episode 168: Total reward = 353.0
# Episode 169: Total reward = 190.0
# Episode 170: Total reward = 304.0
# Episode 171: Total reward = 262.0
# Episode 172: Total reward = 354.0
# Episode 173: Total reward = 307.0
# Episode 174: Total reward = 333.0
# Episode 175: Total reward = 266.0
# Episode 176: Total reward = 294.0
# Episode 177: Total reward = 382.0
# Episode 178: Total reward = 231.0
# Episode 179: Total reward = 220.0
# Episode 180: Total reward = 227.0
# Episode 181: Total reward = 212.0
# Episode 182: Total reward = 211.0
# Episode 183: Total reward = 229.0
# Episode 184: Total reward = 258.0
# Episode 185: Total reward = 257.0
# Episode 186: Total reward = 200.0
# Episode 187: Total reward = 207.0
# Episode 188: Total reward = 332.0
# Episode 189: Total reward = 218.0
# Episode 190: Total reward = 216.0
# Episode 191: Total reward = 332.0
# Episode 192: Total reward = 208.0
# Episode 193: Total reward = 231.0
# Episode 194: Total reward = 215.0
# Episode 195: Total reward = 270.0
# Episode 196: Total reward = 256.0
# Episode 197: Total reward = 230.0
# Episode 198: Total reward = 335.0
# Episode 199: Total reward = 476.0
# Episode 200: Total reward = 340.0
# Episode 201: Total reward = 389.0
# Episode 202: Total reward = 272.0
# Episode 203: Total reward = 297.0
# Episode 204: Total reward = 457.0
# Episode 205: Total reward = 367.0
# Episode 206: Total reward = 500.0
# Episode 207: Total reward = 421.0
# Episode 208: Total reward = 225.0
# Episode 209: Total reward = 179.0
# Episode 210: Total reward = 262.0
# Episode 211: Total reward = 271.0
# Episode 212: Total reward = 500.0
# Episode 213: Total reward = 431.0
# Episode 214: Total reward = 500.0
# Episode 215: Total reward = 317.0
# Episode 216: Total reward = 255.0
# Episode 217: Total reward = 500.0
# Episode 218: Total reward = 500.0
# Episode 219: Total reward = 500.0
# Episode 220: Total reward = 500.0
# Episode 221: Total reward = 220.0
# Episode 222: Total reward = 190.0
# Episode 223: Total reward = 451.0
# Episode 224: Total reward = 500.0
# Episode 225: Total reward = 500.0
# Episode 226: Total reward = 500.0
# Episode 227: Total reward = 491.0
# Episode 228: Total reward = 500.0
# Episode 229: Total reward = 500.0
# Episode 230: Total reward = 500.0
# Episode 231: Total reward = 500.0
# Episode 232: Total reward = 500.0
# Episode 233: Total reward = 500.0
# Episode 234: Total reward = 500.0
# Episode 235: Total reward = 500.0
# Episode 236: Total reward = 262.0
# Episode 237: Total reward = 500.0
# Episode 238: Total reward = 500.0
# Episode 239: Total reward = 371.0
# Episode 240: Total reward = 500.0
# Episode 241: Total reward = 364.0
# Episode 242: Total reward = 274.0
# Episode 243: Total reward = 400.0
# Episode 244: Total reward = 500.0
# Episode 245: Total reward = 500.0
# Episode 246: Total reward = 500.0
# Episode 247: Total reward = 500.0
# Episode 248: Total reward = 292.0
# Episode 249: Total reward = 500.0
# Episode 250: Total reward = 224.0
# Episode 251: Total reward = 205.0
# Episode 252: Total reward = 274.0
# Episode 253: Total reward = 336.0
# Episode 254: Total reward = 500.0
# Episode 255: Total reward = 500.0
# Episode 256: Total reward = 271.0
# Episode 257: Total reward = 242.0
# Episode 258: Total reward = 500.0
# Episode 259: Total reward = 500.0
# Episode 260: Total reward = 500.0
# Episode 261: Total reward = 500.0
# Episode 262: Total reward = 500.0
# Episode 263: Total reward = 500.0
# Episode 264: Total reward = 238.0
# Episode 265: Total reward = 306.0
# Episode 266: Total reward = 500.0
# Episode 267: Total reward = 500.0
# Episode 268: Total reward = 500.0
# Episode 269: Total reward = 500.0
# Episode 270: Total reward = 500.0
# Episode 271: Total reward = 485.0
# Episode 272: Total reward = 500.0
# Episode 273: Total reward = 500.0
# Episode 274: Total reward = 179.0
# Episode 275: Total reward = 175.0
# Episode 276: Total reward = 500.0
# Episode 277: Total reward = 500.0
# Episode 278: Total reward = 500.0
# Episode 279: Total reward = 500.0
# Episode 280: Total reward = 500.0
# Episode 281: Total reward = 500.0
# Episode 282: Total reward = 500.0
# Episode 283: Total reward = 500.0
# Episode 284: Total reward = 147.0
# Episode 285: Total reward = 129.0
# Episode 286: Total reward = 449.0
# Episode 287: Total reward = 472.0
# Episode 288: Total reward = 195.0
# Episode 289: Total reward = 151.0
# Episode 290: Total reward = 240.0
# Episode 291: Total reward = 500.0
# Episode 292: Total reward = 500.0
# Episode 293: Total reward = 500.0
# Episode 294: Total reward = 335.0
# Episode 295: Total reward = 500.0
# Episode 296: Total reward = 500.0
# Episode 297: Total reward = 500.0
# Episode 298: Total reward = 500.0
# Episode 299: Total reward = 442.0
# Episode 300: Total reward = 164.0
# Episode 301: Total reward = 244.0
# Episode 302: Total reward = 221.0
# Episode 303: Total reward = 500.0
# Episode 304: Total reward = 500.0
# Episode 305: Total reward = 500.0
# Episode 306: Total reward = 500.0
# Episode 307: Total reward = 500.0
# Episode 308: Total reward = 500.0
# Episode 309: Total reward = 500.0
# Episode 310: Total reward = 500.0
# Episode 311: Total reward = 500.0
# Episode 312: Total reward = 500.0
# Episode 313: Total reward = 500.0
# Episode 314: Total reward = 500.0
# Episode 315: Total reward = 500.0
# Episode 316: Total reward = 500.0
# Episode 317: Total reward = 500.0
# Episode 318: Total reward = 500.0
# Episode 319: Total reward = 500.0
# Episode 320: Total reward = 500.0
# Episode 321: Total reward = 500.0
# Episode 322: Total reward = 500.0
# Episode 323: Total reward = 500.0
# Episode 324: Total reward = 500.0
# Episode 325: Total reward = 500.0
# Episode 326: Total reward = 500.0
# Episode 327: Total reward = 500.0
# Episode 328: Total reward = 500.0
# Episode 329: Total reward = 500.0
# Episode 330: Total reward = 379.0
# Episode 331: Total reward = 236.0
# Episode 332: Total reward = 320.0
# Episode 333: Total reward = 500.0
# Episode 334: Total reward = 500.0
# Episode 335: Total reward = 500.0
# Episode 336: Total reward = 500.0
# Episode 337: Total reward = 500.0
# Episode 338: Total reward = 500.0
# Episode 339: Total reward = 74.0
# Episode 340: Total reward = 500.0
# Episode 341: Total reward = 500.0
# Episode 342: Total reward = 500.0
# Episode 343: Total reward = 473.0
# Episode 344: Total reward = 500.0
# Episode 345: Total reward = 500.0
# Episode 346: Total reward = 343.0
# Episode 347: Total reward = 224.0
# Episode 348: Total reward = 500.0
# Episode 349: Total reward = 500.0
# Episode 350: Total reward = 337.0
# Episode 351: Total reward = 500.0
# Episode 352: Total reward = 500.0
# Episode 353: Total reward = 294.0
# Episode 354: Total reward = 299.0
# Episode 355: Total reward = 500.0
# Episode 356: Total reward = 298.0
# Episode 357: Total reward = 152.0
# Episode 358: Total reward = 168.0
# Episode 359: Total reward = 241.0
# Episode 360: Total reward = 500.0
# Episode 361: Total reward = 132.0
# Episode 362: Total reward = 118.0
# Episode 363: Total reward = 126.0
# Episode 364: Total reward = 130.0
# Episode 365: Total reward = 500.0
# Episode 366: Total reward = 500.0
# Episode 367: Total reward = 500.0
# Episode 368: Total reward = 500.0
# Episode 369: Total reward = 500.0
# Episode 370: Total reward = 500.0
# Episode 371: Total reward = 500.0
# Episode 372: Total reward = 500.0
# Episode 373: Total reward = 500.0
# Episode 374: Total reward = 500.0
# Episode 375: Total reward = 500.0
# Episode 376: Total reward = 500.0
# Episode 377: Total reward = 500.0
# Episode 378: Total reward = 500.0
# Episode 379: Total reward = 500.0
# Episode 380: Total reward = 500.0
# Episode 381: Total reward = 500.0
# Episode 382: Total reward = 500.0
# Episode 383: Total reward = 500.0
# Episode 384: Total reward = 500.0
# Episode 385: Total reward = 500.0
# Episode 386: Total reward = 500.0
# Episode 387: Total reward = 500.0
# Episode 388: Total reward = 500.0
# Episode 389: Total reward = 500.0
# Episode 390: Total reward = 500.0
# Episode 391: Total reward = 500.0
# Episode 392: Total reward = 500.0
# Episode 393: Total reward = 500.0
# Episode 394: Total reward = 500.0
# Episode 395: Total reward = 500.0
# Episode 396: Total reward = 500.0
# Episode 397: Total reward = 500.0
# Episode 398: Total reward = 500.0
# Episode 399: Total reward = 500.0
# Episode 400: Total reward = 500.0
# Episode 401: Total reward = 500.0
# Episode 402: Total reward = 500.0
# Episode 403: Total reward = 500.0
# Episode 404: Total reward = 500.0
# Episode 405: Total reward = 500.0
# Episode 406: Total reward = 500.0
# Episode 407: Total reward = 189.0
# Episode 408: Total reward = 118.0
# Episode 409: Total reward = 236.0
# Episode 410: Total reward = 184.0
# Episode 411: Total reward = 168.0
# Episode 412: Total reward = 500.0
# Episode 413: Total reward = 500.0
# Episode 414: Total reward = 145.0
# Episode 415: Total reward = 500.0
# Episode 416: Total reward = 141.0
# Episode 417: Total reward = 500.0
# Episode 418: Total reward = 500.0
# Episode 419: Total reward = 500.0
# Episode 420: Total reward = 500.0
# Episode 421: Total reward = 172.0
# Episode 422: Total reward = 500.0
# Episode 423: Total reward = 500.0
# Episode 424: Total reward = 500.0
# Episode 425: Total reward = 301.0
# Episode 426: Total reward = 500.0
# Episode 427: Total reward = 500.0
# Episode 428: Total reward = 500.0
# Episode 429: Total reward = 500.0
# Episode 430: Total reward = 500.0
# Episode 431: Total reward = 297.0
# Episode 432: Total reward = 418.0
# Episode 433: Total reward = 199.0
# Episode 434: Total reward = 469.0
# Episode 435: Total reward = 500.0
# Episode 436: Total reward = 500.0
# Episode 437: Total reward = 500.0
# Episode 438: Total reward = 500.0
# Episode 439: Total reward = 500.0
# Episode 440: Total reward = 500.0
# Episode 441: Total reward = 500.0
# Episode 442: Total reward = 137.0
# Episode 443: Total reward = 500.0
# Episode 444: Total reward = 500.0
# Episode 445: Total reward = 500.0
# Episode 446: Total reward = 500.0
# Episode 447: Total reward = 500.0
# Episode 448: Total reward = 500.0
# Episode 449: Total reward = 500.0
# Episode 450: Total reward = 500.0
# Episode 451: Total reward = 500.0
# Episode 452: Total reward = 500.0
# Episode 453: Total reward = 500.0
# Episode 454: Total reward = 367.0
# Episode 455: Total reward = 192.0
# Episode 456: Total reward = 500.0
# Episode 457: Total reward = 500.0
# Episode 458: Total reward = 500.0
# Episode 459: Total reward = 197.0
# Episode 460: Total reward = 500.0
# Episode 461: Total reward = 500.0
# Episode 462: Total reward = 185.0
# Episode 463: Total reward = 500.0
# Episode 464: Total reward = 500.0
# Episode 465: Total reward = 500.0
# Episode 466: Total reward = 500.0
# Episode 467: Total reward = 500.0
# Episode 468: Total reward = 249.0
# Episode 469: Total reward = 500.0
# Episode 470: Total reward = 161.0
# Episode 471: Total reward = 241.0
# Episode 472: Total reward = 309.0
# Episode 473: Total reward = 460.0
# Episode 474: Total reward = 161.0
# Episode 475: Total reward = 500.0
# Episode 476: Total reward = 500.0
# Episode 477: Total reward = 445.0
# Episode 478: Total reward = 275.0
# Episode 479: Total reward = 500.0
# Episode 480: Total reward = 500.0
# Episode 481: Total reward = 500.0
# Episode 482: Total reward = 500.0
# Episode 483: Total reward = 163.0
# Episode 484: Total reward = 290.0
# Episode 485: Total reward = 500.0
# Episode 486: Total reward = 206.0
# Episode 487: Total reward = 157.0
# Episode 488: Total reward = 266.0
# Episode 489: Total reward = 500.0
# Episode 490: Total reward = 37.0
# Episode 491: Total reward = 80.0
# Episode 492: Total reward = 186.0
# Episode 493: Total reward = 99.0
# Episode 494: Total reward = 157.0
# Episode 495: Total reward = 127.0
# Episode 496: Total reward = 144.0
# Episode 497: Total reward = 500.0
# Episode 498: Total reward = 230.0
# Episode 499: Total reward = 259.0
# Episode 500: Total reward = 500.0
# Episode 501: Total reward = 297.0
# Episode 502: Total reward = 384.0
# Episode 503: Total reward = 314.0
# Episode 504: Total reward = 500.0
# Episode 505: Total reward = 500.0
# Episode 506: Total reward = 500.0
# Episode 507: Total reward = 500.0
# Episode 508: Total reward = 500.0
# Episode 509: Total reward = 500.0
# Episode 510: Total reward = 500.0
# Episode 511: Total reward = 500.0
# Episode 512: Total reward = 500.0
# Episode 513: Total reward = 459.0
# Episode 514: Total reward = 500.0
# Episode 515: Total reward = 500.0
# Episode 516: Total reward = 288.0
# Episode 517: Total reward = 500.0
# Episode 518: Total reward = 500.0
# Episode 519: Total reward = 500.0
# Episode 520: Total reward = 425.0
# Episode 521: Total reward = 500.0
# Episode 522: Total reward = 500.0
# Episode 523: Total reward = 464.0
# Episode 524: Total reward = 500.0
# Episode 525: Total reward = 500.0
# Episode 526: Total reward = 413.0
# Episode 527: Total reward = 500.0
# Episode 528: Total reward = 500.0
# Episode 529: Total reward = 500.0
# Episode 530: Total reward = 500.0
# Episode 531: Total reward = 500.0
# Episode 532: Total reward = 500.0
# Episode 533: Total reward = 368.0
# Episode 534: Total reward = 399.0
# Episode 535: Total reward = 500.0
# Episode 536: Total reward = 269.0
# Episode 537: Total reward = 389.0
# Episode 538: Total reward = 321.0
# Episode 539: Total reward = 270.0
# Episode 540: Total reward = 445.0
# Episode 541: Total reward = 500.0
# Episode 542: Total reward = 134.0
# Episode 543: Total reward = 127.0
# Episode 544: Total reward = 149.0
# Episode 545: Total reward = 500.0
# Episode 546: Total reward = 500.0
# Episode 547: Total reward = 191.0
# Episode 548: Total reward = 500.0
# Episode 549: Total reward = 500.0
# Episode 550: Total reward = 500.0
# Episode 551: Total reward = 500.0
# Episode 552: Total reward = 380.0
# Episode 553: Total reward = 500.0
# Episode 554: Total reward = 354.0
# Episode 555: Total reward = 500.0
# Episode 556: Total reward = 500.0
# Episode 557: Total reward = 383.0
# Episode 558: Total reward = 327.0
# Episode 559: Total reward = 500.0
# Episode 560: Total reward = 202.0
# Episode 561: Total reward = 457.0
# Episode 562: Total reward = 214.0
# Episode 563: Total reward = 216.0
# Episode 564: Total reward = 292.0
# Episode 565: Total reward = 70.0
# Episode 566: Total reward = 268.0
# Episode 567: Total reward = 500.0
# Episode 568: Total reward = 500.0
# Episode 569: Total reward = 228.0
# Episode 570: Total reward = 500.0
# Episode 571: Total reward = 28.0
# Episode 572: Total reward = 500.0
# Episode 573: Total reward = 500.0
# Episode 574: Total reward = 500.0
# Episode 575: Total reward = 500.0
# Episode 576: Total reward = 500.0
# Episode 577: Total reward = 500.0
# Episode 578: Total reward = 33.0
# Episode 579: Total reward = 28.0
# Episode 580: Total reward = 500.0
# Episode 581: Total reward = 26.0
# Episode 582: Total reward = 500.0
# Episode 583: Total reward = 500.0
# Episode 584: Total reward = 500.0
# Episode 585: Total reward = 500.0
# Episode 586: Total reward = 500.0
# Episode 587: Total reward = 500.0
# Episode 588: Total reward = 274.0
# Episode 589: Total reward = 500.0
# Episode 590: Total reward = 500.0
# Episode 591: Total reward = 500.0
# Episode 592: Total reward = 500.0
# Episode 593: Total reward = 500.0
# Episode 594: Total reward = 500.0
# Episode 595: Total reward = 500.0
# Episode 596: Total reward = 255.0
# Episode 597: Total reward = 500.0
# Episode 598: Total reward = 500.0
# Episode 599: Total reward = 500.0
# Episode 600: Total reward = 500.0
# Episode 601: Total reward = 500.0
# Episode 602: Total reward = 191.0
# Episode 603: Total reward = 500.0
# Episode 604: Total reward = 218.0
# Episode 605: Total reward = 500.0
# Episode 606: Total reward = 179.0
# Episode 607: Total reward = 204.0
# Episode 608: Total reward = 215.0
# Episode 609: Total reward = 205.0
# Episode 610: Total reward = 341.0
# Episode 611: Total reward = 255.0
# Episode 612: Total reward = 260.0
# Episode 613: Total reward = 168.0
# Episode 614: Total reward = 500.0
# Episode 615: Total reward = 500.0
# Episode 616: Total reward = 155.0
# Episode 617: Total reward = 128.0
# Episode 618: Total reward = 236.0
# Episode 619: Total reward = 198.0
# Episode 620: Total reward = 353.0
# Episode 621: Total reward = 125.0
# Episode 622: Total reward = 109.0
# Episode 623: Total reward = 147.0
# Episode 624: Total reward = 487.0
# Episode 625: Total reward = 195.0
# Episode 626: Total reward = 239.0
# Episode 627: Total reward = 315.0
# Episode 628: Total reward = 199.0
# Episode 629: Total reward = 101.0
# Episode 630: Total reward = 183.0
# Episode 631: Total reward = 103.0
# Episode 632: Total reward = 54.0
# Episode 633: Total reward = 126.0
# Episode 634: Total reward = 500.0
# Episode 635: Total reward = 191.0
# Episode 636: Total reward = 429.0
# Episode 637: Total reward = 500.0
# Episode 638: Total reward = 500.0
# Episode 639: Total reward = 500.0
# Episode 640: Total reward = 500.0
# Episode 641: Total reward = 500.0
# Episode 642: Total reward = 500.0
# Episode 643: Total reward = 500.0
# Episode 644: Total reward = 500.0
# Episode 645: Total reward = 433.0
# Episode 646: Total reward = 500.0
# Episode 647: Total reward = 478.0
# Episode 648: Total reward = 276.0
# Episode 649: Total reward = 176.0
# Episode 650: Total reward = 247.0
# Episode 651: Total reward = 208.0
# Episode 652: Total reward = 191.0
# Episode 653: Total reward = 337.0
# Episode 654: Total reward = 263.0
# Episode 655: Total reward = 240.0
# Episode 656: Total reward = 369.0
# Episode 657: Total reward = 231.0
# Episode 658: Total reward = 203.0
# Episode 659: Total reward = 203.0
# Episode 660: Total reward = 186.0
# Episode 661: Total reward = 500.0
# Episode 662: Total reward = 192.0
# Episode 663: Total reward = 168.0
# Episode 664: Total reward = 205.0
# Episode 665: Total reward = 232.0
# Episode 666: Total reward = 248.0
# Episode 667: Total reward = 172.0
# Episode 668: Total reward = 189.0
# Episode 669: Total reward = 228.0
# Episode 670: Total reward = 500.0
# Episode 671: Total reward = 203.0
# Episode 672: Total reward = 500.0
# Episode 673: Total reward = 161.0
# Episode 674: Total reward = 202.0
# Episode 675: Total reward = 127.0
# Episode 676: Total reward = 142.0
# Episode 677: Total reward = 154.0
# Episode 678: Total reward = 500.0
# Episode 679: Total reward = 500.0
# Episode 680: Total reward = 500.0
# Episode 681: Total reward = 500.0
# Episode 682: Total reward = 500.0
# Episode 683: Total reward = 500.0
# Episode 684: Total reward = 500.0
# Episode 685: Total reward = 500.0
# Episode 686: Total reward = 500.0
# Episode 687: Total reward = 500.0
# Episode 688: Total reward = 500.0
# Episode 689: Total reward = 500.0
# Episode 690: Total reward = 500.0
# Episode 691: Total reward = 500.0
# Episode 692: Total reward = 500.0
# Episode 693: Total reward = 500.0
# Episode 694: Total reward = 500.0
# Episode 695: Total reward = 500.0
# Episode 696: Total reward = 500.0
# Episode 697: Total reward = 262.0
# Episode 698: Total reward = 239.0
# Episode 699: Total reward = 259.0
# Episode 700: Total reward = 500.0
# Episode 701: Total reward = 500.0
# Episode 702: Total reward = 500.0
# Episode 703: Total reward = 500.0
# Episode 704: Total reward = 500.0
# Episode 705: Total reward = 500.0
# Episode 706: Total reward = 243.0
# Episode 707: Total reward = 189.0
# Episode 708: Total reward = 146.0
# Episode 709: Total reward = 500.0
# Episode 710: Total reward = 232.0
# Episode 711: Total reward = 166.0
# Episode 712: Total reward = 163.0
# Episode 713: Total reward = 112.0
# Episode 714: Total reward = 153.0
# Episode 715: Total reward = 500.0
# Episode 716: Total reward = 182.0
# Episode 717: Total reward = 174.0
# Episode 718: Total reward = 149.0
# Episode 719: Total reward = 156.0
# Episode 720: Total reward = 151.0
# Episode 721: Total reward = 159.0
# Episode 722: Total reward = 155.0
# Episode 723: Total reward = 217.0
# Episode 724: Total reward = 202.0
# Episode 725: Total reward = 192.0
# Episode 726: Total reward = 186.0
# Episode 727: Total reward = 231.0
# Episode 728: Total reward = 174.0
# Episode 729: Total reward = 365.0
# Episode 730: Total reward = 168.0
# Episode 731: Total reward = 333.0
# Episode 732: Total reward = 220.0
# Episode 733: Total reward = 223.0
# Episode 734: Total reward = 212.0
# Episode 735: Total reward = 235.0
# Episode 736: Total reward = 221.0
# Episode 737: Total reward = 348.0
# Episode 738: Total reward = 264.0
# Episode 739: Total reward = 276.0
# Episode 740: Total reward = 249.0
# Episode 741: Total reward = 379.0
# Episode 742: Total reward = 346.0
# Episode 743: Total reward = 317.0
# Episode 744: Total reward = 500.0
# Episode 745: Total reward = 500.0
# Episode 746: Total reward = 399.0
# Episode 747: Total reward = 500.0
# Episode 748: Total reward = 500.0
# Episode 749: Total reward = 135.0
# Episode 750: Total reward = 212.0
# Episode 751: Total reward = 500.0
# Episode 752: Total reward = 500.0
# Episode 753: Total reward = 500.0
# Episode 754: Total reward = 500.0
# Episode 755: Total reward = 500.0
# Episode 756: Total reward = 500.0
# Episode 757: Total reward = 13.0
# Episode 758: Total reward = 187.0
# Episode 759: Total reward = 200.0
# Episode 760: Total reward = 500.0
# Episode 761: Total reward = 500.0
# Episode 762: Total reward = 12.0
# Episode 763: Total reward = 500.0
# Episode 764: Total reward = 9.0
# Episode 765: Total reward = 500.0
# Episode 766: Total reward = 500.0
# Episode 767: Total reward = 9.0
# Episode 768: Total reward = 10.0
# Episode 769: Total reward = 14.0
# Episode 770: Total reward = 11.0
# Episode 771: Total reward = 11.0
# Episode 772: Total reward = 11.0
# Episode 773: Total reward = 10.0
# Episode 774: Total reward = 10.0
# Episode 775: Total reward = 9.0
# Episode 776: Total reward = 10.0
# Episode 777: Total reward = 11.0
# Episode 778: Total reward = 500.0
# Episode 779: Total reward = 500.0
# Episode 780: Total reward = 500.0
# Episode 781: Total reward = 500.0
# Episode 782: Total reward = 500.0
# Episode 783: Total reward = 500.0
# Episode 784: Total reward = 429.0
# Episode 785: Total reward = 500.0
# Episode 786: Total reward = 500.0
# Episode 787: Total reward = 500.0
# Episode 788: Total reward = 500.0
# Episode 789: Total reward = 500.0
# Episode 790: Total reward = 163.0
# Episode 791: Total reward = 192.0
# Episode 792: Total reward = 500.0
# Episode 793: Total reward = 500.0
# Episode 794: Total reward = 500.0
# Episode 795: Total reward = 500.0
# Episode 796: Total reward = 500.0
# Episode 797: Total reward = 500.0
# Episode 798: Total reward = 500.0
# Episode 799: Total reward = 417.0
# Episode 800: Total reward = 500.0
# Episode 801: Total reward = 500.0
# Episode 802: Total reward = 500.0
# Episode 803: Total reward = 500.0
# Episode 804: Total reward = 500.0
# Episode 805: Total reward = 500.0
# Episode 806: Total reward = 500.0
# Episode 807: Total reward = 500.0
# Episode 808: Total reward = 201.0
# Episode 809: Total reward = 231.0
# Episode 810: Total reward = 500.0
# Episode 811: Total reward = 500.0
# Episode 812: Total reward = 500.0
# Episode 813: Total reward = 402.0
# Episode 814: Total reward = 500.0
# Episode 815: Total reward = 500.0
# Episode 816: Total reward = 500.0
# Episode 817: Total reward = 500.0
# Episode 818: Total reward = 500.0
# Episode 819: Total reward = 500.0
# Episode 820: Total reward = 500.0
# Episode 821: Total reward = 500.0
# Episode 822: Total reward = 500.0
# Episode 823: Total reward = 500.0
# Episode 824: Total reward = 366.0
# Episode 825: Total reward = 235.0
# Episode 826: Total reward = 195.0
# Episode 827: Total reward = 10.0
# Episode 828: Total reward = 11.0
# Episode 829: Total reward = 10.0
# Episode 830: Total reward = 200.0
# Episode 831: Total reward = 10.0
# Episode 832: Total reward = 8.0
# Episode 833: Total reward = 12.0
# Episode 834: Total reward = 13.0
# Episode 835: Total reward = 9.0
# Episode 836: Total reward = 12.0
# Episode 837: Total reward = 13.0
# Episode 838: Total reward = 270.0
# Episode 839: Total reward = 66.0
# Episode 840: Total reward = 151.0
# Episode 841: Total reward = 135.0
# Episode 842: Total reward = 160.0
# Episode 843: Total reward = 165.0
# Episode 844: Total reward = 227.0
# Episode 845: Total reward = 500.0
# Episode 846: Total reward = 401.0
# Episode 847: Total reward = 207.0
# Episode 848: Total reward = 228.0
# Episode 849: Total reward = 351.0
# Episode 850: Total reward = 211.0
# Episode 851: Total reward = 500.0
# Episode 852: Total reward = 382.0
# Episode 853: Total reward = 232.0
# Episode 854: Total reward = 500.0
# Episode 855: Total reward = 500.0
# Episode 856: Total reward = 500.0
# Episode 857: Total reward = 500.0
# Episode 858: Total reward = 427.0
# Episode 859: Total reward = 500.0
# Episode 860: Total reward = 500.0
# Episode 861: Total reward = 500.0
# Episode 862: Total reward = 500.0
# Episode 863: Total reward = 422.0
# Episode 864: Total reward = 500.0
# Episode 865: Total reward = 500.0
# Episode 866: Total reward = 500.0
# Episode 867: Total reward = 225.0
# Episode 868: Total reward = 485.0
# Episode 869: Total reward = 431.0
# Episode 870: Total reward = 278.0
# Episode 871: Total reward = 500.0
# Episode 872: Total reward = 500.0
# Episode 873: Total reward = 441.0
# Episode 874: Total reward = 500.0
# Episode 875: Total reward = 384.0
# Episode 876: Total reward = 500.0
# Episode 877: Total reward = 188.0
# Episode 878: Total reward = 409.0
# Episode 879: Total reward = 500.0
# Episode 880: Total reward = 376.0
# Episode 881: Total reward = 432.0
# Episode 882: Total reward = 500.0
# Episode 883: Total reward = 411.0
# Episode 884: Total reward = 500.0
# Episode 885: Total reward = 500.0
# Episode 886: Total reward = 477.0
# Episode 887: Total reward = 435.0
# Episode 888: Total reward = 414.0
# Episode 889: Total reward = 500.0
# Episode 890: Total reward = 500.0
# Episode 891: Total reward = 415.0
# Episode 892: Total reward = 500.0
# Episode 893: Total reward = 500.0
# Episode 894: Total reward = 500.0
# Episode 895: Total reward = 500.0
# Episode 896: Total reward = 500.0
# Episode 897: Total reward = 500.0
# Episode 898: Total reward = 500.0
# Episode 899: Total reward = 139.0
# Episode 900: Total reward = 132.0
# Episode 901: Total reward = 131.0
# Episode 902: Total reward = 135.0
# Episode 903: Total reward = 133.0
# Episode 904: Total reward = 135.0
# Episode 905: Total reward = 139.0
# Episode 906: Total reward = 149.0
# Episode 907: Total reward = 175.0
# Episode 908: Total reward = 135.0
# Episode 909: Total reward = 178.0
# Episode 910: Total reward = 500.0
# Episode 911: Total reward = 500.0
# Episode 912: Total reward = 500.0
# Episode 913: Total reward = 500.0
# Episode 914: Total reward = 500.0
# Episode 915: Total reward = 271.0
# Episode 916: Total reward = 427.0
# Episode 917: Total reward = 154.0
# Episode 918: Total reward = 169.0
# Episode 919: Total reward = 220.0
# Episode 920: Total reward = 357.0
# Episode 921: Total reward = 409.0
# Episode 922: Total reward = 500.0
# Episode 923: Total reward = 157.0
# Episode 924: Total reward = 154.0
# Episode 925: Total reward = 149.0
# Episode 926: Total reward = 66.0
# Episode 927: Total reward = 164.0
# Episode 928: Total reward = 500.0
# Episode 929: Total reward = 500.0
# Episode 930: Total reward = 500.0
# Episode 931: Total reward = 500.0
# Episode 932: Total reward = 500.0
# Episode 933: Total reward = 500.0
# Episode 934: Total reward = 500.0
# Episode 935: Total reward = 500.0
# Episode 936: Total reward = 500.0
# Episode 937: Total reward = 500.0
# Episode 938: Total reward = 500.0
# Episode 939: Total reward = 500.0
# Episode 940: Total reward = 500.0
# Episode 941: Total reward = 500.0
# Episode 942: Total reward = 348.0
# Episode 943: Total reward = 14.0
# Episode 944: Total reward = 11.0
# Episode 945: Total reward = 17.0
# Episode 946: Total reward = 18.0
# Episode 947: Total reward = 201.0
# Episode 948: Total reward = 165.0
# Episode 949: Total reward = 202.0
# Episode 950: Total reward = 204.0
# Episode 951: Total reward = 265.0
# Episode 952: Total reward = 216.0
# Episode 953: Total reward = 259.0
# Episode 954: Total reward = 365.0
# Episode 955: Total reward = 29.0
# Episode 956: Total reward = 23.0
# Episode 957: Total reward = 21.0
# Episode 958: Total reward = 30.0
# Episode 959: Total reward = 23.0
# Episode 960: Total reward = 19.0
# Episode 961: Total reward = 20.0
# Episode 962: Total reward = 500.0
# Episode 963: Total reward = 241.0
# Episode 964: Total reward = 190.0
# Episode 965: Total reward = 190.0
# Episode 966: Total reward = 179.0
# Episode 967: Total reward = 174.0
# Episode 968: Total reward = 190.0
# Episode 969: Total reward = 204.0
# Episode 970: Total reward = 245.0
# Episode 971: Total reward = 263.0
# Episode 972: Total reward = 500.0
# Episode 973: Total reward = 228.0
# Episode 974: Total reward = 225.0
# Episode 975: Total reward = 237.0
# Episode 976: Total reward = 317.0
# Episode 977: Total reward = 276.0
# Episode 978: Total reward = 273.0
# Episode 979: Total reward = 500.0
# Episode 980: Total reward = 405.0
# Episode 981: Total reward = 423.0
# Episode 982: Total reward = 457.0
# Episode 983: Total reward = 500.0
# Episode 984: Total reward = 500.0
# Episode 985: Total reward = 500.0
# Episode 986: Total reward = 500.0
# Episode 987: Total reward = 500.0
# Episode 988: Total reward = 500.0
# Episode 989: Total reward = 500.0
# Episode 990: Total reward = 500.0
# Episode 991: Total reward = 246.0
# Episode 992: Total reward = 194.0
# Episode 993: Total reward = 189.0
# Episode 994: Total reward = 172.0
# Episode 995: Total reward = 183.0
# Episode 996: Total reward = 192.0
# Episode 997: Total reward = 216.0
# Episode 998: Total reward = 223.0
# Episode 999: Total reward = 202.0
# Episode 1000: Total reward = 223.0
